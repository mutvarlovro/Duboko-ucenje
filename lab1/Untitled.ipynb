# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append('/content/drive/MyDrive/Colab Notebooks/lab1')
import mnist_shootout

# %%
sys.path.append('/content/')
import mnist_shootout

# %%
x_train, y_train, x_test,y_test = mnist_shootout.get_data()

# %%
mnist_shootout.zad1(x_train, y_train, param_niter=3000, param_delta=0.1, param_lambda=0)
# Out:
# Step: 0, loss:18.675275802612305
# Step: 100, loss:4.541123867034912
# Step: 200, loss:2.620866298675537
# Step: 300, loss:1.924675464630127
# Step: 400, loss:1.5883350372314453
# Step: 500, loss:1.3903142213821411
# Step: 600, loss:1.2581069469451904
# Step: 700, loss:1.1622871160507202
# Step: 800, loss:1.088912010192871
# Step: 900, loss:1.030439853668213
# Step: 1000, loss:0.9824162721633911
# Step: 1100, loss:0.9420377016067505
# Step: 1200, loss:0.9074496030807495
# Step: 1300, loss:0.8773743510246277
# Step: 1400, loss:0.8509004712104797
# Step: 1500, loss:0.8273570537567139
# Step: 1600, loss:0.8062363266944885
# Step: 1700, loss:0.7871457934379578
# Step: 1800, loss:0.7697761654853821
# Step: 1900, loss:0.753879725933075
# Step: 2000, loss:0.7392562031745911
# Step: 2100, loss:0.7257416844367981
# Step: 2200, loss:0.7132009267807007
# Step: 2300, loss:0.7015212178230286
# Step: 2400, loss:0.6906076669692993
# Step: 2500, loss:0.6803797483444214
# ...

# %%
layers = [784, 100, 10]
mnist_shootout.zad2(x_train, y_train, x_test, y_test, layers, param_niter=3000, param_delta=0.05, param_lambda=0)
# Out:
# Step: 0, loss:2.5495986938476562
# Step: 100, loss:1.988571047782898
# Step: 200, loss:1.9338892698287964
# Step: 300, loss:1.8978701829910278
# Step: 400, loss:1.865906000137329
# Step: 500, loss:1.8356890678405762
# Step: 600, loss:1.8064228296279907
# Step: 700, loss:1.7780967950820923
# Step: 800, loss:1.750570297241211
# Step: 900, loss:1.7238166332244873
# Step: 1000, loss:1.6977721452713013
# Step: 1100, loss:1.672358512878418
# Step: 1200, loss:1.6475694179534912
# Step: 1300, loss:1.6234029531478882
# Step: 1400, loss:1.599823236465454
# Step: 1500, loss:1.5768215656280518
# Step: 1600, loss:1.5543599128723145
# Step: 1700, loss:1.5323951244354248
# Step: 1800, loss:1.5109331607818604
# Step: 1900, loss:1.48995041847229
# Step: 2000, loss:1.4694457054138184
# Step: 2100, loss:1.4494125843048096
# Step: 2200, loss:1.4298137426376343
# Step: 2300, loss:1.410671591758728
# Step: 2400, loss:1.3919671773910522
# Step: 2500, loss:1.3736768960952759
# ...

# %%
layers = [784, 100, 10]
mnist_shootout.zad2(x_train, y_train, x_test, y_test, layers, param_niter=3000, param_delta=0.1, param_lambda=0)
# Out:
# Step: 0, loss:2.5028984546661377
# Step: 100, loss:1.913212776184082
# Step: 200, loss:1.8249715566635132
# Step: 300, loss:1.7506375312805176
# Step: 400, loss:1.6818146705627441
# Step: 500, loss:1.617938756942749
# Step: 600, loss:1.5585857629776
# Step: 700, loss:1.503248929977417
# Step: 800, loss:1.4515653848648071
# Step: 900, loss:1.4032695293426514
# Step: 1000, loss:1.358077883720398
# Step: 1100, loss:1.3157554864883423
# Step: 1200, loss:1.2760742902755737
# Step: 1300, loss:1.2388454675674438
# Step: 1400, loss:1.2039002180099487
# Step: 1500, loss:1.171081781387329
# Step: 1600, loss:1.1402431726455688
# Step: 1700, loss:1.1112390756607056
# Step: 1800, loss:1.0839333534240723
# Step: 1900, loss:1.0582034587860107
# Step: 2000, loss:1.0339423418045044
# Step: 2100, loss:1.0110316276550293
# Step: 2200, loss:0.9893707036972046
# Step: 2300, loss:0.9688631296157837
# Step: 2400, loss:0.949393093585968
# Step: 2500, loss:0.9309580326080322
# ...

# %%
mnist_shootout.zad3(x_train, y_train, x_test, y_test, param_niter=3000, param_lambda=0)
# Out:
# Step: 0, loss:11.329819679260254
# Step: 100, loss:3.6572792530059814
# Step: 200, loss:2.3506076335906982
# Step: 300, loss:1.8241767883300781
# Step: 400, loss:1.5433741807937622
# Step: 500, loss:1.3677825927734375
# Step: 600, loss:1.2464675903320312
# Step: 700, loss:1.1567589044570923
# Step: 800, loss:1.087167739868164
# Step: 900, loss:1.031245470046997
# Step: 1000, loss:0.9850860238075256
# Step: 1100, loss:0.9461593627929688
# Step: 1200, loss:0.9127427339553833
# Step: 1300, loss:0.8836245536804199
# Step: 1400, loss:0.8579308986663818
# Step: 1500, loss:0.8350171446800232
# Step: 1600, loss:0.8143978118896484
# Step: 1700, loss:0.7957000732421875
# Step: 1800, loss:0.7786333560943604
# Step: 1900, loss:0.7629664540290833
# Step: 2000, loss:0.7485136985778809
# Step: 2100, loss:0.7351225018501282
# Step: 2200, loss:0.7226665616035461
# Step: 2300, loss:0.7110393047332764
# Step: 2400, loss:0.7001509666442871
# Step: 2500, loss:0.689923882484436
# ...

# %%
mnist_shootout.zad3(x_train, y_train, x_test, y_test, param_niter=3000, param_lambda=0.1)
# Out:
# Step: 0, loss:15.540691375732422
# Step: 100, loss:1.3499536514282227
# Step: 200, loss:0.7998412847518921
# Step: 300, loss:0.7713907957077026
# Step: 400, loss:0.7699476480484009
# Step: 500, loss:0.7697556018829346
# Step: 600, loss:0.769706130027771
# Step: 700, loss:0.7696928381919861
# Step: 800, loss:0.7696895599365234
# Step: 900, loss:0.7696888446807861
# Step: 1000, loss:0.7696886658668518
# Step: 1100, loss:0.7696886658668518
# Step: 1200, loss:0.7696887254714966
# Step: 1300, loss:0.7696886658668518
# Step: 1400, loss:0.7696886658668518
# Step: 1500, loss:0.7696886658668518
# Step: 1600, loss:0.7696886658668518
# Step: 1700, loss:0.7696886658668518
# Step: 1800, loss:0.7696886658668518
# Step: 1900, loss:0.7696886658668518
# Step: 2000, loss:0.7696886658668518
# Step: 2100, loss:0.7696886658668518
# Step: 2200, loss:0.7696886658668518
# Step: 2300, loss:0.7696886658668518
# Step: 2400, loss:0.7696886658668518
# Step: 2500, loss:0.7696886658668518
# ...

# %%
mnist_shootout.zad3(x_train, y_train, x_test, y_test, param_niter=3000, param_lambda=1.0)
# Out:
# Step: 0, loss:10.701092720031738
# Step: 100, loss:1.6298471689224243
# Step: 200, loss:1.6298515796661377
# Step: 300, loss:1.6298515796661377
# Step: 400, loss:1.6298515796661377
# Step: 500, loss:1.6298515796661377
# Step: 600, loss:1.6298515796661377
# Step: 700, loss:1.6298515796661377
# Step: 800, loss:1.6298515796661377
# Step: 900, loss:1.6298515796661377
# Step: 1000, loss:1.6298515796661377
# Step: 1100, loss:1.6298515796661377
# Step: 1200, loss:1.6298515796661377
# Step: 1300, loss:1.6298515796661377
# Step: 1400, loss:1.6298515796661377
# Step: 1500, loss:1.6298515796661377
# Step: 1600, loss:1.6298515796661377
# Step: 1700, loss:1.6298515796661377
# Step: 1800, loss:1.6298515796661377
# Step: 1900, loss:1.6298515796661377
# Step: 2000, loss:1.6298515796661377
# Step: 2100, loss:1.6298515796661377
# Step: 2200, loss:1.6298515796661377
# Step: 2300, loss:1.6298515796661377
# Step: 2400, loss:1.6298515796661377
# Step: 2500, loss:1.6298515796661377
# ...

# %%
mnist_shootout.zad67(x_train, y_train, param_niter=3000, task=6)
# Out:
# Step: 0, loss:13.59000301361084
# Step: 100, loss:12.511038780212402
# Step: 200, loss:11.555865287780762
# Step: 300, loss:10.717306137084961
# Step: 400, loss:9.985248565673828
# Step: 500, loss:9.34754753112793
# Step: 600, loss:8.789424896240234
# Step: 700, loss:8.294384002685547
# Step: 800, loss:7.848016738891602
# Step: 900, loss:7.4394450187683105
# Step: 1000, loss:7.060823917388916
# Step: 1100, loss:6.706840515136719
# Step: 1200, loss:6.37401008605957
# Step: 1300, loss:6.059986591339111
# Step: 1400, loss:5.763054370880127
# Step: 1500, loss:5.481925964355469
# Step: 1600, loss:5.215601444244385
# Step: 1700, loss:4.963180065155029
# Step: 1800, loss:4.723865509033203
# Step: 1900, loss:4.497003078460693
# Step: 2000, loss:4.282019138336182
# Step: 2100, loss:4.078392505645752
# Step: 2200, loss:3.8856775760650635
# Step: 2300, loss:3.7034971714019775
# Step: 2400, loss:3.5315093994140625
# Step: 2500, loss:3.3693783283233643
# Step: 2600, loss:3.216752529144287
# ...

# %%
mnist_shootout.zad67(x_train, y_train, param_niter=3000, task=7)
# Out:
# Step: 0, loss:15.923768043518066
# Step: 100, loss:14.756240844726562
# Step: 200, loss:13.71862506866455
# Step: 300, loss:12.793540000915527
# Step: 400, loss:11.966814994812012
# Step: 500, loss:11.226356506347656
# Step: 600, loss:10.560388565063477
# Step: 700, loss:9.958666801452637
# Step: 800, loss:9.412603378295898
# Step: 900, loss:8.914651870727539
# Step: 1000, loss:8.458353996276855
# Step: 1100, loss:8.038399696350098
# Step: 1200, loss:7.650479316711426
# Step: 1300, loss:7.29102897644043
# Step: 1400, loss:6.957007884979248
# Step: 1500, loss:6.6458282470703125
# Step: 1600, loss:6.355344295501709
# Step: 1700, loss:6.083799362182617
# Step: 1800, loss:5.829720497131348
# Step: 1900, loss:5.5917863845825195
# Step: 2000, loss:5.3687591552734375
# Step: 2100, loss:5.159492492675781
# Step: 2200, loss:4.962941646575928
# Step: 2300, loss:4.778163433074951
# Step: 2400, loss:4.604305744171143
# Step: 2500, loss:4.440588474273682
# Step: 2600, loss:4.286289691925049
# ...

# %%
mnist_shootout.zad8(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-adcdb0325564> in <module>()
# ----> 1 mnist_shootout.zad8(x_train, y_train)
#
# AttributeError: module 'mnist_shootout' has no attribute 'zad8'
